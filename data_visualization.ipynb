# %% [markdown]
# # Visualizing the 3D Tensor image data

# %%
from utils import fix_randomness, load_cifar10_trainset, generate_dataloader, show_images

# %%
fix_randomness(12345)
cifar10_trainset = load_cifar10_trainset()
cifar10_trainloader = generate_dataloader(cifar10_trainset)

# Take the first batch of images
cifar10_images = enumerate(cifar10_trainloader)
batch_idx, (cifar10_data, cifar10_targets) = next(cifar10_images)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(f"The target of a 3D RGB Tensor image is {cifar10_targets[0]}.\n")
print(f"The shape of a 3D RGB Tensor image is {cifar10_data[0].shape}.\n")
print(f"The data of a 3D RGB Tensor image is {cifar10_data[0]}.")
# Out:
# The target of a 3D RGB Tensor image is 6.
#
# The shape of a 3D RGB Tensor image is torch.Size([3, 32, 32]).
#
# The data of a 3D RGB Tensor image is tensor([[[ 0.1686,  0.1216,  0.0902,  ..., -0.1451, -0.1843, -0.2157],
#          [ 0.1294,  0.0824,  0.0510,  ..., -0.1765, -0.2157, -0.2471],
#          [ 0.0980,  0.0588,  0.0353,  ..., -0.2078, -0.2471, -0.2784],
#          ...,
#          [-0.2471, -0.2627, -0.2627,  ...,  0.3333,  0.5373,  0.4039],
#          [-0.2549, -0.2627, -0.3098,  ...,  0.1843,  0.3098,  0.3255],
#          [-0.2627, -0.3176, -0.3255,  ...,  0.1765,  0.1137,  0.3569]],
#
#         [[ 0.4196,  0.3725,  0.3333,  ...,  0.0980,  0.0667,  0.0275],
#          [ 0.3725,  0.3255,  0.2941,  ...,  0.0431,  0.0039, -0.0275],
#          [ 0.3412,  0.3020,  0.2706,  ..., -0.0039, -0.0353, -0.0745],
#          ...,
#          [-0.0824, -0.1294, -0.1216,  ...,  0.3098,  0.5137,  0.3882],
#          [-0.0745, -0.0902, -0.1843,  ...,  0.1608,  0.2863,  0.3176],
# ...

# %%
# Visualize the first six images of the first batch
for i in range(6):
    show_images(cifar10_data[i], cifar10_targets[i])
